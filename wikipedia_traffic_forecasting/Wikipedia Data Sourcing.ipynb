# %%
import pandas as pd
import requests
import json
import ast

# %% [markdown]
# # The API
#
# ---
#
# ## What is it?
#
# The Pageview API is a collection of REST endpoints that serve analytical data about pageviews in Wikimedia's projects. It's developed and maintained by WMF's Analytics and Services teams, and is implemented using Analytics' Hadoop cluster and RESTBase. This API is meant to be used by anyone interested in pageview statistics on Wikimedia wikis: Foundation, communities, and the rest of the world.
#
# Data goes back to May 1st, 2015.
#
# ## How to access
#
# The API is accessible via https at wikimedia.org/api/rest_v1. As it is public, it doesn't need authentication and it supports CORS. The urls are structured like this:
#
# ```/metrics/pageviews/{endpoint}/{parameter 1}/{parameter 2}/.../{parameter N}```

# %% [markdown]
# https://wikitech.wikimedia.org/wiki/Analytics/AQS/Pageviews
#
# https://wikimedia.org/api/rest_v1/

# %% [markdown]
# ## Daily counts

# %% [markdown]
# Get a pageview count timeseries of en.wikipedia's article Albert Enstein for the month of October 2015

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/all-agents/Albert_Einstein/daily/2015100100/2015103100')
x = r.json()
a = pd.DataFrame(pd.read_json(json.dumps(x)))
b = a['items'].apply(pd.Series)
b
# Out:
#         access       agent          article granularity       project  \
# 0   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 1   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 2   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 3   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 4   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 5   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 6   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 7   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 8   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 9   all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 10  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 11  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 12  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 13  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 14  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 15  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 16  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 17  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 18  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 19  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 20  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 21  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 22  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 23  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 24  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 25  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 26  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 27  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 28  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 29  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
# 30  all-access  all-agents  Albert_Einstein       daily  en.wikipedia
#
#      timestamp  views
# 0   2015100100  18860
# 1   2015100200  20816
# 2   2015100300  16009
# 3   2015100400  19494
# 4   2015100500  21198
# 5   2015100600  22515
# 6   2015100700  22269
# 7   2015100800  20835
# 8   2015100900  18319
# 9   2015101000  17088
# 10  2015101100  18522
# 11  2015101200  20251
# 12  2015101300  20765
# 13  2015101400  21677
# 14  2015101500  20694
# 15  2015101600  18597
# 16  2015101700  19252
# 17  2015101800  19257
# 18  2015101900  22160
# 19  2015102000  22280
# 20  2015102100  23067
# 21  2015102200  22469
# 22  2015102300  19218
# 23  2015102400  17942
# 24  2015102500  20262
# 25  2015102600  22290
# 26  2015102700  23170
# 27  2015102800  23288
# 28  2015102900  24300
# 29  2015103000  20720
# 30  2015103100  16380

# %% [markdown]
# Get a pageview count timeseries of de.wikipedia's article Johann Wolfgang von Goethe from October 13th 2015 to October 27th 2015 counting only the pageviews generated by human users

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/de.wikipedia/all-access/user/Johann_Wolfgang_von_Goethe/daily/2015101300/2015102700')
x = r.json()
c = pd.DataFrame(pd.read_json(json.dumps(x)))
d = c['items'].apply(pd.Series)
d
# Out:
#         access agent                     article granularity       project  \
# 0   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 1   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 2   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 3   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 4   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 5   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 6   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 7   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 8   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 9   all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 10  all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 11  all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 12  all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 13  all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
# 14  all-access  user  Johann_Wolfgang_von_Goethe       daily  de.wikipedia
#
#      timestamp  views
# 0   2015101300   2934
# 1   2015101400   3104
# 2   2015101500   2938
# 3   2015101600   2420
# 4   2015101700   2305
# 5   2015101800   2739
# 6   2015101900   3344
# 7   2015102000   3068
# 8   2015102100   3048
# 9   2015102200   2973
# 10  2015102300   2315
# 11  2015102400   2372
# 12  2015102500   3180
# 13  2015102600   2992
# 14  2015102700   2890

# %% [markdown]
# Get the number of pageviews of es.wiktionary's entry hoy generated via mobile web on November 1st, 2015

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/es.wiktionary/mobile-web/all-agents/hoy/daily/2015110100/2015110100')
x = r.json()
e = pd.DataFrame(pd.read_json(json.dumps(x)))
f = e['items'].apply(pd.Series)
f
# Out:
#        access       agent article granularity        project   timestamp  \
# 0  mobile-web  all-agents     hoy       daily  es.wiktionary  2015110100
#
#    views
# 0      2

# %% [markdown]
# ## Monthly counts

# %% [markdown]
# Get a monthly pageview count de.wikipedia's article Barack_Obama for the year 2016

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/de.wikipedia/all-access/all-agents/Barack_Obama/monthly/2016010100/2016123100')
x = r.json()
g = pd.DataFrame(pd.read_json(json.dumps(x)))
h = g['items'].apply(pd.Series)
h
# Out:
#         access       agent       article granularity       project  \
# 0   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 1   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 2   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 3   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 4   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 5   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 6   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 7   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 8   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 9   all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 10  all-access  all-agents  Barack_Obama     monthly  de.wikipedia
# 11  all-access  all-agents  Barack_Obama     monthly  de.wikipedia
#
#      timestamp   views
# 0   2016010100  112458
# 1   2016020100  114036
# 2   2016030100  134238
# 3   2016040100  127099
# 4   2016050100   96700
# 5   2016060100   76502
# 6   2016070100   85732
# 7   2016080100   75056
# 8   2016090100   87647
# 9   2016100100  117706
# 10  2016110100  438171
# 11  2016120100   85157

# %% [markdown]
# ## Slice and dice pageview counts

# %% [markdown]
# Get a daily pageview count timeseries of all projects for the month of October 2015

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/all-projects/all-access/all-agents/daily/2015100100/2015103100')
x = r.json()
i = pd.DataFrame(pd.read_json(json.dumps(x)))
j = i['items'].apply(pd.Series)
j
# Out:
#         access       agent granularity       project   timestamp      views
# 0   all-access  all-agents       daily  all-projects  2015100100  614236484
# 1   all-access  all-agents       daily  all-projects  2015100200  594526358
# 2   all-access  all-agents       daily  all-projects  2015100300  580496576
# 3   all-access  all-agents       daily  all-projects  2015100400  629356620
# 4   all-access  all-agents       daily  all-projects  2015100500  653133733
# 5   all-access  all-agents       daily  all-projects  2015100600  666303084
# 6   all-access  all-agents       daily  all-projects  2015100700  658445283
# 7   all-access  all-agents       daily  all-projects  2015100800  623923450
# 8   all-access  all-agents       daily  all-projects  2015100900  598831259
# 9   all-access  all-agents       daily  all-projects  2015101000  583322547
# 10  all-access  all-agents       daily  all-projects  2015101100  617763420
# 11  all-access  all-agents       daily  all-projects  2015101200  654394930
# 12  all-access  all-agents       daily  all-projects  2015101300  660440793
# 13  all-access  all-agents       daily  all-projects  2015101400  662553907
# 14  all-access  all-agents       daily  all-projects  2015101500  658846298
# 15  all-access  all-agents       daily  all-projects  2015101600  618500357
# 16  all-access  all-agents       daily  all-projects  2015101700  588265145
# 17  all-access  all-agents       daily  all-projects  2015101800  638210282
# 18  all-access  all-agents       daily  all-projects  2015101900  662884748
# 19  all-access  all-agents       daily  all-projects  2015102000  665035854
# 20  all-access  all-agents       daily  all-projects  2015102100  658649066
# 21  all-access  all-agents       daily  all-projects  2015102200  652446868
# 22  all-access  all-agents       daily  all-projects  2015102300  613922801
# 23  all-access  all-agents       daily  all-projects  2015102400  584331435
# 24  all-access  all-agents       daily  all-projects  2015102500  634359177
# 25  all-access  all-agents       daily  all-projects  2015102600  663503835
# 26  all-access  all-agents       daily  all-projects  2015102700  660075982
# 27  all-access  all-agents       daily  all-projects  2015102800  642061807
# 28  all-access  all-agents       daily  all-projects  2015102900  638477568
# 29  all-access  all-agents       daily  all-projects  2015103000  600144674
# 30  all-access  all-agents       daily  all-projects  2015103100  574366555

# %% [markdown]
# Get an hourly timeseries of all project's pageviews belonging to human users visiting the mobile app on October 1st, 2015

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/all-projects/mobile-app/user/hourly/2015100100/2015100123')
x = r.json()
k = pd.DataFrame(pd.read_json(json.dumps(x)))
l = k['items'].apply(pd.Series)
l
# Out:
#         access agent granularity       project   timestamp   views
# 0   mobile-app  user      hourly  all-projects  2015100100  190238
# 1   mobile-app  user      hourly  all-projects  2015100101  197807
# 2   mobile-app  user      hourly  all-projects  2015100102  199163
# 3   mobile-app  user      hourly  all-projects  2015100103  193361
# 4   mobile-app  user      hourly  all-projects  2015100104  190302
# 5   mobile-app  user      hourly  all-projects  2015100105  188688
# 6   mobile-app  user      hourly  all-projects  2015100106  188102
# 7   mobile-app  user      hourly  all-projects  2015100107  184144
# 8   mobile-app  user      hourly  all-projects  2015100108  179789
# 9   mobile-app  user      hourly  all-projects  2015100109  186098
# 10  mobile-app  user      hourly  all-projects  2015100110  202800
# 11  mobile-app  user      hourly  all-projects  2015100111  222248
# 12  mobile-app  user      hourly  all-projects  2015100112  242742
# 13  mobile-app  user      hourly  all-projects  2015100113  242020
# 14  mobile-app  user      hourly  all-projects  2015100114  245243
# 15  mobile-app  user      hourly  all-projects  2015100115  251194
# 16  mobile-app  user      hourly  all-projects  2015100116  263099
# 17  mobile-app  user      hourly  all-projects  2015100117  275895
# 18  mobile-app  user      hourly  all-projects  2015100118  309551
# 19  mobile-app  user      hourly  all-projects  2015100119  343598
# 20  mobile-app  user      hourly  all-projects  2015100120  350728
# 21  mobile-app  user      hourly  all-projects  2015100121  302361
# 22  mobile-app  user      hourly  all-projects  2015100122  248188
# 23  mobile-app  user      hourly  all-projects  2015100123  202323

# %% [markdown]
# Get the number of pageviews of ca.wikipedia generated by spiders on mobile web on November 1st, 2015

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/ca.wikipedia/mobile-web/spider/daily/2015110100/2015110100')
x = r.json()
m = pd.DataFrame(pd.read_json(json.dumps(x)))
n = m['items'].apply(pd.Series)
n
# Out:
#        access   agent granularity       project   timestamp  views
# 0  mobile-web  spider       daily  ca.wikipedia  2015110100  31434

# %% [markdown]
# ## Most viewed articles

# %% [markdown]
# Get the top 1000 most visited articles from en.wikipedia for October 10th, 2015

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2015/10/10')
x = r.json()
o = pd.DataFrame(pd.read_json(json.dumps(x)))
p = o['items'].apply(pd.Series)
p
# Out:
#        access                                           articles day month  \
# 0  all-access  [{'article': 'Main_Page', 'views': 18793503, '...  10    10
#
#         project  year
# 0  en.wikipedia  2015

# %% [markdown]
# Get the top 1000 articles from pt.wikipedia visited via the mobile app on November 1st, 2015

# %%
r = requests.get(url='http://wikimedia.org/api/rest_v1/metrics/pageviews/top/pt.wikipedia/mobile-app/2015/11/01')
x = r.json()
q = pd.DataFrame(pd.read_json(json.dumps(x)))
r = q['items'].apply(pd.Series)
r
# Out:
#        access                                           articles day month  \
# 0  mobile-app  [{'article': 'Wikipedia:Página_principal', 'vi...  01    11
#
#         project  year
# 0  pt.wikipedia  2015

# %% [markdown]
# Get the top 1000 most visited articles from en.wikisource for all days in October, 2015

# %%
r = requests.get(url='https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikisource/all-access/2015/10/all-days')
x = r.json()
s = pd.DataFrame(pd.read_json(json.dumps(x)))
t = s['items'].apply(pd.Series)
t
# Out:
#        access                                           articles       day  \
# 0  all-access  [{'article': 'Main_Page', 'views': 92640, 'ran...  all-days
#
#   month        project  year
# 0    10  en.wikisource  2015

# %% [markdown]
# ## Pageviews for ALL projects

# %% [markdown]
# ### Daily

# %%
r = requests.get(url='https://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/all-projects/all-access/all-agents/daily/2015100100/2015103000')
x = r.json()
u = pd.DataFrame(pd.read_json(json.dumps(x)))
v = u['items'].apply(pd.Series)
v
# Out:
#         access       agent granularity       project   timestamp      views
# 0   all-access  all-agents       daily  all-projects  2015100100  614236484
# 1   all-access  all-agents       daily  all-projects  2015100200  594526358
# 2   all-access  all-agents       daily  all-projects  2015100300  580496576
# 3   all-access  all-agents       daily  all-projects  2015100400  629356620
# 4   all-access  all-agents       daily  all-projects  2015100500  653133733
# 5   all-access  all-agents       daily  all-projects  2015100600  666303084
# 6   all-access  all-agents       daily  all-projects  2015100700  658445283
# 7   all-access  all-agents       daily  all-projects  2015100800  623923450
# 8   all-access  all-agents       daily  all-projects  2015100900  598831259
# 9   all-access  all-agents       daily  all-projects  2015101000  583322547
# 10  all-access  all-agents       daily  all-projects  2015101100  617763420
# 11  all-access  all-agents       daily  all-projects  2015101200  654394930
# 12  all-access  all-agents       daily  all-projects  2015101300  660440793
# 13  all-access  all-agents       daily  all-projects  2015101400  662553907
# 14  all-access  all-agents       daily  all-projects  2015101500  658846298
# 15  all-access  all-agents       daily  all-projects  2015101600  618500357
# 16  all-access  all-agents       daily  all-projects  2015101700  588265145
# 17  all-access  all-agents       daily  all-projects  2015101800  638210282
# 18  all-access  all-agents       daily  all-projects  2015101900  662884748
# 19  all-access  all-agents       daily  all-projects  2015102000  665035854
# 20  all-access  all-agents       daily  all-projects  2015102100  658649066
# 21  all-access  all-agents       daily  all-projects  2015102200  652446868
# 22  all-access  all-agents       daily  all-projects  2015102300  613922801
# 23  all-access  all-agents       daily  all-projects  2015102400  584331435
# 24  all-access  all-agents       daily  all-projects  2015102500  634359177
# 25  all-access  all-agents       daily  all-projects  2015102600  663503835
# 26  all-access  all-agents       daily  all-projects  2015102700  660075982
# 27  all-access  all-agents       daily  all-projects  2015102800  642061807
# 28  all-access  all-agents       daily  all-projects  2015102900  638477568
# 29  all-access  all-agents       daily  all-projects  2015103000  600144674

# %% [markdown]
# ### Monthly

# %%
r = requests.get(url='https://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/all-projects/all-access/all-agents/monthly/2015100100/2016103000')
x = r.json()
w = pd.DataFrame(pd.read_json(json.dumps(x)))
x = w['items'].apply(pd.Series)
x
# Out:
#         access       agent granularity       project   timestamp        views
# 0   all-access  all-agents     monthly  all-projects  2015100100  19551810896
# 1   all-access  all-agents     monthly  all-projects  2015110100  19269221845
# 2   all-access  all-agents     monthly  all-projects  2015120100  19012482674
# 3   all-access  all-agents     monthly  all-projects  2016010100  20865413322
# 4   all-access  all-agents     monthly  all-projects  2016020100  19491676571
# 5   all-access  all-agents     monthly  all-projects  2016030100  20053032262
# 6   all-access  all-agents     monthly  all-projects  2016040100  19999876232
# 7   all-access  all-agents     monthly  all-projects  2016050100  19918073483
# 8   all-access  all-agents     monthly  all-projects  2016060100  18955145337
# 9   all-access  all-agents     monthly  all-projects  2016070100  19188170725
# 10  all-access  all-agents     monthly  all-projects  2016080100  20068666400
# 11  all-access  all-agents     monthly  all-projects  2016090100  19359161888
