# %% [markdown]
# # Lesson 3: Demos

# %% [markdown]
# ## Normality Demo
# http://hamelg.blogspot.com/2015/11/python-for-data-analysis-part-21.html

# %%
#General imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ggplot import mtcars
import scipy as sp

# %matplotlib inline
# Out:
# /Users/zoealdington/anaconda/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /Users/zoealdington/anaconda/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# /Users/zoealdington/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# Although the mean and median both give us some sense of the center of a distribution, they aren't always the same. The *median* gives us a value that **splits the data into two halves** while the *mean* is a **numeric average,** so extreme values can have a significant impact on the mean.
#
# In a symmetric distribution, the mean and median will be the same. Let's investigate with a density plot:

# %%
norm_data = pd.DataFrame(np.random.normal(size=100000))

norm_data.plot(kind="density",
              figsize=(10,10))


plt.vlines(norm_data.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.4,
           linewidth=5.0)

plt.vlines(norm_data.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.4, 
           linewidth=2.0,
           color="red")

# %%
print(norm_data.mean())
print(norm_data.std())
print(norm_data.skew())
print(norm_data.kurt())
#norm_data.as_matrix
# Out:
# 0    0.002538
# dtype: float64
# 0    0.999933
# dtype: float64
# 0   -0.007071
# dtype: float64
# 0   -0.002355
# dtype: float64

# %%
np.random.normal(size=100000)
# Out:
# array([-1.65887004,  0.67435896, -1.89605015, ...,  0.93814699,
#        -2.5029338 , -0.6195744 ])

# %% [markdown]
# In the plot above, the mean and median are both so close to zero that the red median line lies on top of the thicker black line drawn at the mean.
#
# In skewed distributions, the mean tends to get pulled in the direction of the skew, while the median tends to resist the effects of skew:

# %%
skewed_data = pd.DataFrame(np.random.exponential(size=100000))

skewed_data.plot(kind="density",
              figsize=(10,10),
              xlim=(-1,5))


plt.vlines(skewed_data.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.8,
           linewidth=5.0)

plt.vlines(skewed_data.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.8, 
           linewidth=2.0,
           color="red")

fixed_skewed_data = skewed_data.apply(np.log)

fixed_skewed_data.plot(kind="density",
              figsize=(10,10),
              xlim=(-10,10))


plt.vlines(fixed_skewed_data.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.8,
           linewidth=5.0)

plt.vlines(fixed_skewed_data.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.8, 
           linewidth=2.0,
           color="red")


print(skewed_data.skew())
print(skewed_data.kurt())

print(fixed_skewed_data.skew())
print(fixed_skewed_data.kurt())
# Out:
# 0    2.028544
# dtype: float64
# 0    6.255922
# dtype: float64
# 0   -1.168178
# dtype: float64
# 0    2.633384
# dtype: float64

# %% [markdown]
# Notice that the mean is also influenced heavily by outliers, while the median resists the influence of outliers:

# %%
norm_data = np.random.normal(size=50)
outliers = np.random.normal(15, size=3) #loc is the mean, scale is the standard deviation, size is the sample size
combined_data = pd.DataFrame(np.concatenate((norm_data, outliers), axis=0))

combined_data.plot(kind="density",
              figsize=(10,10),
              xlim=(-5,20))


plt.vlines(combined_data.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.2,
           linewidth=5.0)

plt.vlines(combined_data.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.2, 
           linewidth=2.0,
           color="red")

print(fixed_skewed_data.skew())
print(fixed_skewed_data.kurt())
# Out:
# 0   -1.168178
# dtype: float64
# 0    2.633384
# dtype: float64

# %% [markdown]
# Since the median tends to resist the effects of skewness and outliers, it is known a "robust" statistic.
#
# The median generally gives a better sense of the typical value in a distribution with significant skew or outliers.

# %%
comp1 = np.random.normal(0, 1, size=200) # N(0, 1)
comp2 = np.random.normal(10, 2, size=200) # N(10, 2)

df1 = pd.Series(comp1)
df2 = pd.Series(comp2)

# %% [markdown]
# ### Skewness and Kurtosis
# *Skewness* measures the **skew or asymmetry of a distribution** while *Kurtosis* measures the **"peakedness" of a distribution**.
#
# We won't go into the exact calculations behind these, but they are essentially just statistics that take the idea of variance a step further: while variance involves squaring deviations from the mean, skewness involves cubing deviations from the mean, and kurtosis involves raising deviations from the mean to the 4th power.
#
# Pandas has built in functions for checking skewness and kurtosis, df.skew() and df.kurt() respectively:

# %%
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars["qsec"].skew()  # Check skewness
# Out:
# 0.40634662924049031

# %%
test = mtcars["qsec"]  # Check skewness
test.plot(kind="density",
              figsize=(10,10))


plt.vlines(test.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.7,
           linewidth=5.0)

plt.vlines(test.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.7, 
           linewidth=2.0,
           color="red")

# %%
mtcars["qsec"].kurt()  # Check kurtosis
# Out:
# 0.8649306528645293

# %% [markdown]
# To explore these two measures further, let's create some dummy data and inspect it:

# %%
norm_data = np.random.normal(size=100000)
skewed_data = np.concatenate((np.random.normal(size=35000)+2, 
                                 np.random.exponential(size=65000)), 
                             axis=0)
uniform_data = np.random.uniform(0,2, size=100000)
peaked_data = np.concatenate((np.random.exponential(size=50000),
                             np.random.exponential(size=50000)*(-1)),
                             axis=0)

data_df = pd.DataFrame({"norm":norm_data,
                       "skewed":skewed_data,
                       "uniform":uniform_data,
                       "peaked":peaked_data})

# %% [markdown]
# ## Types of distributions

# %%
data_df["norm"].plot(kind="density", xlim=(-5,5))

# %%
data_df["peaked"].plot(kind="density", xlim=(-5,5))

# %%
data_df["skewed"].plot(kind="density", xlim=(-5,5))

# %%
data_df["uniform"].plot(kind="density", xlim=(-5,5))

# %%
data_df.skew()
# Out:
# norm       0.003587
# peaked     0.020191
# skewed     1.035003
# uniform   -0.000276
# dtype: float64

# %% [markdown]
# ### All together

# %%
data_df.plot(kind="density",
            xlim=(-5,5))

# %% [markdown]
# ### Skewness

# %% [markdown]
# Now let's check the skewness of each of these distributions.
#
# Since skewness measures asymmetry, we'd expect to see low skewness for all of the distributions except the skewed one, because all the others are roughly symmetric:

# %%
data_df.skew()
# Out:
# norm       0.003587
# peaked     0.020191
# skewed     1.035003
# uniform   -0.000276
# dtype: float64

# %% [markdown]
# ### Kurtosis

# %% [markdown]
# Now let's check kurtosis. Since kurtosis measures peakedness, we'd expect the flat (uniform) distribution to have low kurtosis while the distributions with sharper peaks should have higher kurtosis.

# %%
data_df.kurt()
# Out:
# norm       0.005569
# peaked     3.116627
# skewed     1.593620
# uniform   -1.199006
# dtype: float64

# %% [markdown]
# As we can see from the output, the normally distributed data has a kurtosis near zero, the flat distribution has negative kurtosis, and the two pointier distributions have positive kurtosis.

# %% [markdown]
# ## Class Variable Demo

# %% [markdown]
# ### Class/Dummy Variables
# We want to represent categorical variables numerically, but we can't simply code them as 0=rural, 1=suburban, 2=urban because that would imply an **ordered relationship** between suburban and urban (suggesting that urban is somehow "twice" the suburban category, which doesn't make sense).
#
# Why do we only need **two dummy variables, not three?** Because two dummies capture all of the information about the Area feature, and implicitly defines rural as the reference level.
#
# In general, if you have a categorical feature with k levels, you create k-1 dummy variables.

# %% [markdown]
# #### Create three dummy variables using get_dummies, then exclude the first dummy column
# my_categorical_var_dummies = pd.get_dummies(my_categorical_var, prefix='Area').iloc[:, 1:]

# %%
# read data into a DataFrame
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Handling Categorical Predictors with Two Categories
#
# Up to now, all of our predictors have been numeric. What if one of our predictors was categorical?
#
# Let's create a new feature called "Size," and randomly assign observations to be small or large:

# %%
# set a seed for reproducibility
np.random.seed(12345)

# create a Series of booleans in which roughly half are True
nums = np.random.rand(len(data))
mask_large = nums > 0.3

# initially set Size to small, then change roughly half to be large
data['Size'] = 'small'
data['nums'] = nums
data.loc[mask_large, 'Size'] = 'large'
data.head()
# Out:
#       TV  radio  newspaper  sales   Size      nums
# 1  230.1   37.8       69.2   22.1  large  0.929616
# 2   44.5   39.3       45.1   10.4  large  0.316376
# 3   17.2   45.9       69.3    9.3  small  0.183919
# 4  151.5   41.3       58.5   18.5  small  0.204560
# 5  180.8   10.8       58.4   12.9  large  0.567725

# %%
mask_large = nums > 0.5
mask_large
data['Size'] = 'small'
data.loc[mask_large,'Size']
# Out:
# 1      small
# 5      small
# 6      small
# 7      small
# 8      small
# 9      small
# 10     small
# 11     small
# 12     small
# 16     small
# 17     small
# 18     small
# 19     small
# 20     small
# 21     small
# 22     small
# 26     small
# 27     small
# 28     small
# 29     small
# 32     small
# 33     small
# 36     small
# 37     small
# 39     small
# 40     small
# 41     small
# 42     small
# 43     small
# 49     small
#        ...
# 138    small
# 139    small
# 142    small
# 146    small
# 148    small
# 151    small
# 152    small
# 156    small
# 157    small
# 158    small
# 160    small
# 165    small
# 166    small
# 167    small
# 168    small
# 170    small
# 171    small
# 173    small
# 174    small
# 175    small
# 177    small
# 178    small
# 179    small
# 183    small
# 186    small
# 188    small
# 191    small
# 192    small
# 195    small
# 200    small
# Name: Size, Length: 108, dtype: object

# %% [markdown]
# For scikit-learn, we need to represent all data numerically.
#
# If the feature only has two categories, we can simply create a dummy variable that represents the categories as a binary value.

# %%
# create a new Series called IsLarge
data['IsLarge'] = data.Size.map({'small':0, 'large':1})
data.head()
# Out:
#       TV  radio  newspaper  sales   Size      nums  IsLarge
# 1  230.1   37.8       69.2   22.1  small  0.929616        0
# 2   44.5   39.3       45.1   10.4  small  0.316376        0
# 3   17.2   45.9       69.3    9.3  small  0.183919        0
# 4  151.5   41.3       58.5   18.5  small  0.204560        0
# 5  180.8   10.8       58.4   12.9  small  0.567725        0

# %% [markdown]
# ### Handling Categorical Predictors with More than Two Categories
#
# Let's create a new feature called Area, and randomly assign observations to be rural, suburban, or urban:

# %%
# set a seed for reproducibility
np.random.seed(123456)

# assign roughly one third of observations to each group
nums = np.random.rand(len(data))
mask_suburban = (nums > 0.33) & (nums < 0.66)
mask_urban = nums > 0.66
data['Area'] = 'rural'
data.loc[mask_suburban, 'Area'] = 'suburban'
data.loc[mask_urban, 'Area'] = 'urban'
data.head()
# Out:
#       TV  radio  newspaper  sales   Size      nums  IsLarge      Area
# 1  230.1   37.8       69.2   22.1  small  0.929616        0     rural
# 2   44.5   39.3       45.1   10.4  small  0.316376        0     urban
# 3   17.2   45.9       69.3    9.3  small  0.183919        0     rural
# 4  151.5   41.3       58.5   18.5  small  0.204560        0     urban
# 5  180.8   10.8       58.4   12.9  small  0.567725        0  suburban

# %% [markdown]
# We have to represent Area numerically, but we can't simply code it as 0=rural, 1=suburban, 2=urban because that would imply an ordered relationship between suburban and urban (and thus urban is somehow "twice" the suburban category).
#
# Instead, we create another dummy variable:

# %%
# create three dummy variables using get_dummies, then exclude the first dummy column
area_dummies = pd.get_dummies(data.Area, prefix='Area').iloc[:, 1:] #could also do drop_first=True

# concatenate the dummy variable columns onto the original DataFrame (axis=0 means rows, axis=1 means columns)
data = pd.concat([data, area_dummies], axis=1)
data.head()
# Out:
#       TV  radio  newspaper  sales   Size      nums  IsLarge      Area  \
# 1  230.1   37.8       69.2   22.1  small  0.929616        0     rural
# 2   44.5   39.3       45.1   10.4  small  0.316376        0     urban
# 3   17.2   45.9       69.3    9.3  small  0.183919        0     rural
# 4  151.5   41.3       58.5   18.5  small  0.204560        0     urban
# 5  180.8   10.8       58.4   12.9  small  0.567725        0  suburban
#
#    Area_suburban  Area_urban  Area_suburban  Area_urban
# 1              0           0              0           0
# 2              0           1              0           1
# 3              0           0              0           0
# 4              0           1              0           1
# 5              1           0              1           0

# %%
pd.get_dummies(data.Area, prefix='Area').head()
# Out:
#    Area_rural  Area_suburban  Area_urban
# 1           1              0           0
# 2           0              0           1
# 3           1              0           0
# 4           0              0           1
# 5           0              1           0

# %%
pd.get_dummies(data.Area, prefix='Area').iloc[:, 1:] #exclude the first dummy column as it is not needed
pd.get_dummies(data.Area, prefix='Area',drop_first=True).head() #equivalent to above
# Out:
#    Area_suburban  Area_urban
# 1              0           0
# 2              0           1
# 3              0           0
# 4              0           1
# 5              1           0
